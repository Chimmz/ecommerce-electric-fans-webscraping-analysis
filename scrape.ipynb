# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import re

# %%
rating = re.findall(r'\d.?\d? out of 5', '4.5 out of 5(3840)')
rating
# Out:
# ['4.5 out of 5']

# %%
def scrape_product_info(prod):
  link = prod.find('a', class_='core')
  prod_id = link['href'].split('-')[-1].replace('.html', '')
  full_prod_id = link['href'].replace('.html', '').replace('/', '')
  brand = link['data-gtm-brand']
  category4 = link['data-ga4-item_category4']

  info = prod.find('div', class_='info')
  name = info.h3.text
  price = info.find('div', class_='prc').text
  print({'price': info.find('div', class_='prc')})

  old_price = info.find('div', class_='old')
  print({'old_price': info.find('div', class_='old')})

  discount = info.find('div', class_='bdg _dsct _sm')
  print({'discount': info.find('div', class_='bdg _dsct _sm')})

  try:
    reviews_info = info.find('div', class_='rev').text
    rating = re.findall(r'\d.?\d? out of 5', reviews_info)[0].replace('out of 5', '').strip()
    total_reviews = re.findall(r"\(\d+\)", reviews_info)[0].replace('(', '').replace(')', '').strip()
    print({'reviews_info': reviews_info}, '\n\n')
  except AttributeError as e:
    print('reviews_info isn\'t available')
    rating = ''
    total_reviews = ''

  prod = {
    'id': prod_id,
    'full_id': full_prod_id,
    'brand': brand,
    'category4': category4,
    'name': name,
    'price': price,
    'old_price': old_price.text if old_price else '',
    'discount': discount.text if discount else '',
    'rating': rating,
    'total_reviews': total_reviews,
  }
  print('In scrape_product_info: ', prod)
  return prod

# %%
def save_products(products):
  with open('data/products.csv', 'a') as f:
    writer = csv.DictWriter(f, fieldnames=products[0].keys(), lineterminator='\n')
    writer.writeheader()
    writer.writerows(products)

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
# url = f'https://www.jumia.com.ng/catalog/?q=fans&page={page}#catalog-listing'
# response = requests.get(url, headers=headers)
# response

# %%
def fetch_products(page):
  pg_products = []
  try:
    url = f'https://www.jumia.com.ng/catalog/?q=fans&page={page}#catalog-listing'
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    
    for prod in soup.find_all('article', class_='prd'):
      pg_products.append(scrape_product_info(prod))
      
    return pg_products
  except Exception as e:
    print('An error happened: ', e)

# %%
def run():
  all_products = []
  MAX_PAGES = 50
  current_page = 1

  while (current_page <= MAX_PAGES):
    all_products.extend(fetch_products(current_page))
    print(f'Page {current_page} done!')
    current_page += 1

  save_products(all_products)
run()
# Out:
# {'price': <div class="prc">₦ 19,400</div>}
# {'old_price': <div class="old">₦ 25,000</div>}
# {'discount': <div class="bdg _dsct _sm">22%</div>}
# {'reviews_info': '4.2 out of 5(270)'}
#
#
# In scrape_product_info:  {'id': '334520266', 'full_id': 'ox-spacetek-18-inches-standing-fan-334520266', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Spacetek 18 Inches Standing Fan', 'price': '₦ 19,400', 'old_price': '₦ 25,000', 'discount': '22%', 'rating': '4.2', 'total_reviews': '270'}
# {'price': <div class="prc">₦ 40,740</div>}
# {'old_price': <div class="old">₦ 50,740</div>}
# {'discount': <div class="bdg _dsct _sm">20%</div>}
# {'reviews_info': '4.3 out of 5(891)'}
#
#
# In scrape_product_info:  {'id': '76698431', 'full_id': 'binatone-16-inches-standing-fan-a1691-black-2-years-warranty-76698431', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 16 Inches Standing Fan (A1691) - Black + 2 Years Warranty', 'price': '₦ 40,740', 'old_price': '₦ 50,740', 'discount': '20%', 'rating': '4.3', 'total_reviews': '891'}
# {'price': <div class="prc">₦ 69,500</div>}
# {'old_price': <div class="old">₦ 85,000</div>}
# {'discount': <div class="bdg _dsct _sm">18%</div>}
# {'reviews_info': '4.7 out of 5(13)'}
#
#
# In scrape_product_info:  {'id': '346616815', 'full_id': 'glamstar-18-inches-rechargeable-standing-fan-white-346616815', 'brand': 'Glamstar', 'category4': 'Household Fans', 'name': 'Glamstar 18 Inches Rechargeable Standing Fan White', 'price': '₦ 69,500', 'old_price': '₦ 85,000', 'discount': '18%', 'rating': '4.7', 'total_reviews': '13'}
# {'price': <div class="prc">₦ 39,990</div>}
# {'old_price': <div class="old">₦ 50,000</div>}
# {'discount': <div class="bdg _dsct _sm">20%</div>}
# {'reviews_info': '4.3 out of 5(442)'}
#
#
# In scrape_product_info:  {'id': '46157327', 'full_id': 'cloud-energy-16-10watt-dc-standing-fan-with-remote-control-inverter-fance-dc-409-black-46157327', 'brand': 'Cloud Energy', 'category4': 'Household Fans', 'name': "Cloud Energy 16'' 10watt DC Standing Fan With Remote Control-INVERTER FAN(CE-DC-409) - Black", 'price': '₦ 39,990', 'old_price': '₦ 50,000', 'discount': '20%', 'rating': '4.3', 'total_reviews': '442'}
# {'price': <div class="prc">₦ 20,475</div>}
# {'old_price': <div class="old">₦ 25,475</div>}
# {'discount': <div class="bdg _dsct _sm">20%</div>}
# {'reviews_info': '4 out of 5(3840)'}
#
#
# In scrape_product_info:  {'id': '82939109', 'full_id': 'nexus-16-inches-standing-fan-nx-4400b-black-82939109', 'brand': 'Nexus', 'category4': 'Household Fans', 'name': 'Nexus 16 Inches Standing Fan (NX 4400B) - Black', 'price': '₦ 20,475', 'old_price': '₦ 25,475', 'discount': '20%', 'rating': '4', 'total_reviews': '3840'}
# {'price': <div class="prc">₦ 25,900</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '3.9 out of 5(38)'}
#
#
# In scrape_product_info:  {'id': 'mpg3352822', 'full_id': '18-inches-standing-fan-heavy-breeze-ox-mpg3352822', 'brand': 'Generic', 'category4': 'Household Fans', 'name': '18-inches Standing Fan, Heavy Breeze', 'price': '₦ 25,900', 'old_price': '', 'discount': '', 'rating': '3.9', 'total_reviews': '38'}
# {'price': <div class="prc">₦ 38,799</div>}
# {'old_price': <div class="old">₦ 92,000</div>}
# {'discount': <div class="bdg _dsct _sm">58%</div>}
# {'reviews_info': '4.4 out of 5(71)'}
#
#
# In scrape_product_info:  {'id': 'mpg4125084', 'full_id': '16-10watt-dc-standing-fan-with-remote-control-inverter-fan-cloud-energy-mpg4125084', 'brand': 'Cloud Energy', 'category4': 'Household Fans', 'name': "Cloud Energy 16'' 10watt DC Standing Fan With Remote Control-INVERTER FAN", 'price': '₦ 38,799', 'old_price': '₦ 92,000', 'discount': '58%', 'rating': '4.4', 'total_reviews': '71'}
# {'price': <div class="prc">₦ 29,999</div>}
# {'old_price': <div class="old">₦ 32,500</div>}
# {'discount': <div class="bdg _dsct _sm">8%</div>}
# {'reviews_info': '3.8 out of 5(13)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147329', 'full_id': '18-standing-fan-hexa-18-inch-ox-mpg3147329', 'brand': 'Ox', 'category4': 'Household Fans', 'name': "Ox 18'' Standing Fan  - 18 Inch", 'price': '₦ 29,999', 'old_price': '₦ 32,500', 'discount': '8%', 'rating': '3.8', 'total_reviews': '13'}
# {'price': <div class="prc">₦ 56,900</div>}
# {'old_price': <div class="old">₦ 72,000</div>}
# {'discount': <div class="bdg _dsct _sm">21%</div>}
# {'reviews_info': '4.7 out of 5(23)'}
#
#
# In scrape_product_info:  {'id': '238829587', 'full_id': 'ox-2-sets-of-18-standing-fan-promo-238829587', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 2 Sets Of 18” Standing Fan - Promo', 'price': '₦ 56,900', 'old_price': '₦ 72,000', 'discount': '21%', 'rating': '4.7', 'total_reviews': '23'}
# {'price': <div class="prc">₦ 74,998</div>}
# {'old_price': <div class="old">₦ 99,000</div>}
# {'discount': <div class="bdg _dsct _sm">24%</div>}
# {'reviews_info': '3.7 out of 5(554)'}
#
#
# In scrape_product_info:  {'id': '118781591', 'full_id': 'duravolt-16-inches-3-in-1-rechargeable-fan-solar-panel-2-bulbs-118781591', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 16 Inches -3 In 1 Rechargeable Fan +Solar Panel + 2-Bulbs', 'price': '₦ 74,998', 'old_price': '₦ 99,000', 'discount': '24%', 'rating': '3.7', 'total_reviews': '554'}
# {'price': <div class="prc">₦ 65,000</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '304841225', 'full_id': 'tses-mini-industrial-antique-fan-30w-304841225', 'brand': 'TSES', 'category4': 'Household Fans', 'name': 'TSES MINI INDUSTRIAL ANTIQUE FAN-30w', 'price': '₦ 65,000', 'old_price': '', 'discount': '', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 36,900</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '3.5 out of 5(4)'}
#
#
# In scrape_product_info:  {'id': '41499869', 'full_id': 'power-deluxe-16-wall-fan-blue-41499869', 'brand': 'Power Deluxe', 'category4': 'Household Fans', 'name': 'Power Deluxe 16" Wall Fan BLUE', 'price': '₦ 36,900', 'old_price': '', 'discount': '', 'rating': '3.5', 'total_reviews': '4'}
# {'price': <div class="prc">₦ 25,990</div>}
# {'old_price': <div class="old">₦ 120,000</div>}
# {'discount': <div class="bdg _dsct _sm">78%</div>}
# {'reviews_info': '4.3 out of 5(268)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147324', 'full_id': '18-inches-standing-fan-plastic-blade-ox-mpg3147324', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18-Inches Standing Fan (Plastic Blade)+ Free Gift Inside', 'price': '₦ 25,990', 'old_price': '₦ 120,000', 'discount': '78%', 'rating': '4.3', 'total_reviews': '268'}
# {'price': <div class="prc">₦ 24,190</div>}
# {'old_price': <div class="old">₦ 67,900</div>}
# {'discount': <div class="bdg _dsct _sm">64%</div>}
# {'reviews_info': '4.3 out of 5(89)'}
#
#
# In scrape_product_info:  {'id': '52531160', 'full_id': 'ox-18-plus-standing-fan-18-inches-52531160', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" PLUS STANDING FAN - 18 Inches', 'price': '₦ 24,190', 'old_price': '₦ 67,900', 'discount': '64%', 'rating': '4.3', 'total_reviews': '89'}
# {'price': <div class="prc">₦ 44,999</div>}
# {'old_price': <div class="old">₦ 75,000</div>}
# {'discount': <div class="bdg _dsct _sm">40%</div>}
# {'reviews_info': '4.3 out of 5(180)'}
#
#
# In scrape_product_info:  {'id': 'mpg3632957', 'full_id': '18-inches-acdc-standing-fan-remote-non-rechargeable-qasa-mpg3632957', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches AC/DC Standing Fan + Remote (Non Rechargeable)', 'price': '₦ 44,999', 'old_price': '₦ 75,000', 'discount': '40%', 'rating': '4.3', 'total_reviews': '180'}
# {'price': <div class="prc">₦ 13,068</div>}
# {'old_price': <div class="old">₦ 25,670</div>}
# {'discount': <div class="bdg _dsct _sm">49%</div>}
# {'reviews_info': '3.3 out of 5(3)'}
#
#
# In scrape_product_info:  {'id': '303231929', 'full_id': 'generic-portable-home-small-air-humidifier-3-speed-fan-green-303231929', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Portable Home Small Air Humidifier 3-Speed Fan - Green', 'price': '₦ 13,068', 'old_price': '₦ 25,670', 'discount': '49%', 'rating': '3.3', 'total_reviews': '3'}
# {'price': <div class="prc">₦ 22,000</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '293178033', 'full_id': 'generic-foldable-rechargeable-fan-adjustable-desktop-with-usb-293178033', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Foldable Rechargeable Fan Adjustable Desktop With USB', 'price': '₦ 22,000', 'old_price': '', 'discount': '', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 27,000</div>}
# {'old_price': <div class="old">₦ 45,000</div>}
# {'discount': <div class="bdg _dsct _sm">40%</div>}
# {'reviews_info': '4.5 out of 5(6)'}
#
#
# In scrape_product_info:  {'id': '336374678', 'full_id': 'itel-electric-fan16-inch-lite-7-blade-imitation-natural-wind-336374678', 'brand': 'itel', 'category4': 'Household Fans', 'name': 'itel Electric Fan16 Inch-Lite 7-Blade Imitation Natural Wind', 'price': '₦ 27,000', 'old_price': '₦ 45,000', 'discount': '40%', 'rating': '4.5', 'total_reviews': '6'}
# {'price': <div class="prc">₦ 65,000</div>}
# {'old_price': <div class="old">₦ 90,000</div>}
# {'discount': <div class="bdg _dsct _sm">28%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '356188270', 'full_id': 'generic-16-solar-rechargeable-fan-with-25watts-solar-panel-356188270', 'brand': 'Generic', 'category4': 'Household Fans', 'name': '16" Solar Rechargeable Fan With 25watts Solar Panel', 'price': '₦ 65,000', 'old_price': '₦ 90,000', 'discount': '28%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 96,990</div>}
# {'old_price': <div class="old">₦ 160,000</div>}
# {'discount': <div class="bdg _dsct _sm">39%</div>}
# {'reviews_info': '4.3 out of 5(24)'}
#
#
# In scrape_product_info:  {'id': 'mpg3632948', 'full_id': 'standing-fan-industrial-20-inches-ox-mpg3632948', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Standing Fan Industrial 20" Inches', 'price': '₦ 96,990', 'old_price': '₦ 160,000', 'discount': '39%', 'rating': '4.3', 'total_reviews': '24'}
# {'price': <div class="prc">₦ 28,890</div>}
# {'old_price': <div class="old">₦ 35,000</div>}
# {'discount': <div class="bdg _dsct _sm">17%</div>}
# {'reviews_info': '4.1 out of 5(58)'}
#
#
# In scrape_product_info:  {'id': '77057858', 'full_id': 'duravolt-17-inches-standing-fan-dsf-173-black-77057858', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 17 Inches Standing Fan (DSF-173) - Black', 'price': '₦ 28,890', 'old_price': '₦ 35,000', 'discount': '17%', 'rating': '4.1', 'total_reviews': '58'}
# {'price': <div class="prc">₦ 28,500</div>}
# {'old_price': <div class="old">₦ 35,000</div>}
# {'discount': <div class="bdg _dsct _sm">19%</div>}
# {'reviews_info': '3.3 out of 5(3)'}
#
#
# In scrape_product_info:  {'id': '288013512', 'full_id': 'duravolt-7inches-rechargeable-table-fansolar-panelbulbs-288013512', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 7inches  Rechargeable Table Fan+Solar Panel+Bulbs', 'price': '₦ 28,500', 'old_price': '₦ 35,000', 'discount': '19%', 'rating': '3.3', 'total_reviews': '3'}
# {'price': <div class="prc">₦ 5,699</div>}
# {'old_price': <div class="old">₦ 15,294</div>}
# {'discount': <div class="bdg _dsct _sm">63%</div>}
# {'reviews_info': '3.2 out of 5(324)'}
#
#
# In scrape_product_info:  {'id': '290890919', 'full_id': 'ace-elec-8.7-inches-rechargeable-table-fan-290890919', 'brand': 'Ace Elec', 'category4': 'Household Fans', 'name': 'Ace Elec 8.7 inches Rechargeable Table Fan', 'price': '₦ 5,699', 'old_price': '₦ 15,294', 'discount': '63%', 'rating': '3.2', 'total_reviews': '324'}
# {'price': <div class="prc">₦ 72,899</div>}
# {'old_price': <div class="old">₦ 110,750</div>}
# {'discount': <div class="bdg _dsct _sm">34%</div>}
# {'reviews_info': '4.5 out of 5(349)'}
#
#
# In scrape_product_info:  {'id': '21766096', 'full_id': 'binatone-20-inches-typhoon-series-stand-fan-ts-2020-mk-2-black-and-red-21766096', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 20 Inches Typhoon Series Stand Fan (TS-2020 MK 2) - Black And Red', 'price': '₦ 72,899', 'old_price': '₦ 110,750', 'discount': '34%', 'rating': '4.5', 'total_reviews': '349'}
# {'price': <div class="prc">₦ 28,500</div>}
# {'old_price': <div class="old">₦ 35,000</div>}
# {'discount': <div class="bdg _dsct _sm">19%</div>}
# {'reviews_info': '5 out of 5(3)'}
#
#
# In scrape_product_info:  {'id': '321215172', 'full_id': 'ox-18-plus-wall-fan-18-inch-321215172', 'brand': 'Ox', 'category4': 'Household Fans', 'name': "Ox 18 Plus Wall Fan - 18'' Inch", 'price': '₦ 28,500', 'old_price': '₦ 35,000', 'discount': '19%', 'rating': '5', 'total_reviews': '3'}
# {'price': <div class="prc">₦ 22,500</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '318360019', 'full_id': 'generic-foldable-charging-fan-low-noise-adjustable-desktop-usb-318360019', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Foldable Charging Fan Low Noise Adjustable Desktop Usb', 'price': '₦ 22,500', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 51,000</div>}
# {'old_price': <div class="old">₦ 60,000</div>}
# {'discount': <div class="bdg _dsct _sm">15%</div>}
# {'reviews_info': '4.2 out of 5(62)'}
#
#
# In scrape_product_info:  {'id': 'mpg4128539', 'full_id': '18-inches-acdc-standing-fan-remote-non-rechargeable-qasa-mpg4128539', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches AC/DC Standing Fan + Remote (Non Rechargeable)', 'price': '₦ 51,000', 'old_price': '₦ 60,000', 'discount': '15%', 'rating': '4.2', 'total_reviews': '62'}
# {'price': <div class="prc">₦ 11,880</div>}
# {'old_price': <div class="old">₦ 24,876</div>}
# {'discount': <div class="bdg _dsct _sm">52%</div>}
# {'reviews_info': '3.3 out of 5(29)'}
#
#
# In scrape_product_info:  {'id': '277586279', 'full_id': 'generic-7200mah-rechargeable-fan-usb-folding-telescopic-7.7-inch-max-277586279', 'brand': 'Generic', 'category4': 'Household Fans', 'name': '7200MaH Rechargeable Fan USB Folding Telescopic 7.7 Inch Max', 'price': '₦ 11,880', 'old_price': '₦ 24,876', 'discount': '52%', 'rating': '3.3', 'total_reviews': '29'}
# {'price': <div class="prc">₦ 42,500</div>}
# {'old_price': <div class="old">₦ 60,000</div>}
# {'discount': <div class="bdg _dsct _sm">29%</div>}
# {'reviews_info': '3.8 out of 5(4)'}
#
#
# In scrape_product_info:  {'id': '350096121', 'full_id': 'duravolt-dc-18-inches-standing-fan-with-adapter.-350096121', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt DC 18 Inches Standing Fan With Adapter.', 'price': '₦ 42,500', 'old_price': '₦ 60,000', 'discount': '29%', 'rating': '3.8', 'total_reviews': '4'}
# {'price': <div class="prc">₦ 52,799</div>}
# {'old_price': <div class="old">₦ 78,920</div>}
# {'discount': <div class="bdg _dsct _sm">33%</div>}
# {'reviews_info': '4.3 out of 5(294)'}
#
#
# In scrape_product_info:  {'id': '10105472', 'full_id': 'binatone-18-inch-standing-fan-ts-1880-mk2-black-10105472', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 18 Inch Standing Fan TS-1880 (MK2) - Black', 'price': '₦ 52,799', 'old_price': '₦ 78,920', 'discount': '33%', 'rating': '4.3', 'total_reviews': '294'}
# {'price': <div class="prc">₦ 27,500</div>}
# {'old_price': <div class="old">₦ 33,000</div>}
# {'discount': <div class="bdg _dsct _sm">17%</div>}
# {'reviews_info': '4.4 out of 5(224)'}
#
#
# In scrape_product_info:  {'id': 'mpg4310459', 'full_id': '18-plus-standing-fan-18-inches-ox-mpg4310459', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" STANDING ELECTRIC FAN - 18 Inches', 'price': '₦ 27,500', 'old_price': '₦ 33,000', 'discount': '17%', 'rating': '4.4', 'total_reviews': '224'}
# {'price': <div class="prc">₦ 25,990</div>}
# {'old_price': <div class="old">₦ 145,000</div>}
# {'discount': <div class="bdg _dsct _sm">82%</div>}
# {'reviews_info': '3 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '259434414', 'full_id': 'ox-18-standing-electric-fan-free-gift-259434414', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" Standing Electric Fan + Free Gift', 'price': '₦ 25,990', 'old_price': '₦ 145,000', 'discount': '82%', 'rating': '3', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 45,699</div>}
# {'old_price': <div class="old">₦ 70,250</div>}
# {'discount': <div class="bdg _dsct _sm">35%</div>}
# {'reviews_info': '4 out of 5(22)'}
#
#
# In scrape_product_info:  {'id': '202234870', 'full_id': 'binatone-1.6m-stand-fan-a-1691-mk2-black-202234870', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 1.6M Stand Fan (A-1691 (MK2) - Black', 'price': '₦ 45,699', 'old_price': '₦ 70,250', 'discount': '35%', 'rating': '4', 'total_reviews': '22'}
# {'price': <div class="prc">₦ 12,000</div>}
# {'old_price': <div class="old">₦ 34,876</div>}
# {'discount': <div class="bdg _dsct _sm">66%</div>}
# {'reviews_info': '3.7 out of 5(120)'}
#
#
# In scrape_product_info:  {'id': '254991929', 'full_id': 'generic-7200mah-rechargeable-fan-usb-folding-telescopic-7.7-inch-max-254991929', 'brand': 'Generic', 'category4': 'Household Fans', 'name': '7200MaH Rechargeable Fan USB Folding Telescopic 7.7 Inch Max', 'price': '₦ 12,000', 'old_price': '₦ 34,876', 'discount': '66%', 'rating': '3.7', 'total_reviews': '120'}
# {'price': <div class="prc">₦ 29,990</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '3.8 out of 5(10)'}
#
#
# In scrape_product_info:  {'id': '279711676', 'full_id': 'bb-18-inches-wall-industrial-fan-2-years-warranty-279711676', 'brand': 'BB', 'category4': 'Household Fans', 'name': "BB 18' Inches Wall Industrial Fan 2 Years Warranty", 'price': '₦ 29,990', 'old_price': '', 'discount': '', 'rating': '3.8', 'total_reviews': '10'}
# {'price': <div class="prc">₦ 95,699</div>}
# {'old_price': <div class="old">₦ 109,000</div>}
# {'discount': <div class="bdg _dsct _sm">12%</div>}
# {'reviews_info': '4 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '315301864', 'full_id': 'binatone-rechargeable-fan-with-lithium-ion-batteries-rcfm-1875-315301864', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone Rechargeable Fan With Lithium-Ion Batteries RCFM-1875', 'price': '₦ 95,699', 'old_price': '₦ 109,000', 'discount': '12%', 'rating': '4', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 89,500</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4 out of 5(4)'}
#
#
# In scrape_product_info:  {'id': 'mpg3352813', 'full_id': 'industrial-18-inches-standing-fan-ox-mpg3352813', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Industrial 18" Inches Standing Fan', 'price': '₦ 89,500', 'old_price': '', 'discount': '', 'rating': '4', 'total_reviews': '4'}
# {'price': <div class="prc">₦ 45,999</div>}
# {'old_price': <div class="old">₦ 55,000</div>}
# {'discount': <div class="bdg _dsct _sm">16%</div>}
# {'reviews_info': '3.5 out of 5(14)'}
#
#
# In scrape_product_info:  {'id': '259463905', 'full_id': 'duravolt-18-inches-acdc-standing-fan-non-rechargeable-259463905', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 18 Inches AC/DC Standing Fan  (Non Rechargeable)', 'price': '₦ 45,999', 'old_price': '₦ 55,000', 'discount': '16%', 'rating': '3.5', 'total_reviews': '14'}
# {'price': <div class="prc">₦ 49,999</div>}
# {'old_price': <div class="old">₦ 65,000</div>}
# {'discount': <div class="bdg _dsct _sm">23%</div>}
# {'reviews_info': '4 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': '288794173', 'full_id': 'duravolt-solar-ceiling-fan-acdc-288794173', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt Solar Ceiling Fan AC/DC', 'price': '₦ 49,999', 'old_price': '₦ 65,000', 'discount': '23%', 'rating': '4', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 83,930</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.3 out of 5(40)'}
#
#
# In scrape_product_info:  {'id': '265594953', 'full_id': 'ox-18-inches-2-in-1-rechargeable-fan-with-solar-panel-265594953', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18 Inches 2 In 1 Rechargeable Fan With Solar Panel', 'price': '₦ 83,930', 'old_price': '', 'discount': '', 'rating': '4.3', 'total_reviews': '40'}
# Page 1 done!
# {'price': <div class="prc">₦ 185,000</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.5 out of 5(20)'}
#
#
# In scrape_product_info:  {'id': 'mpg3632911', 'full_id': '26-inch-industrial-standing-water-acmist-fan-26-generic-mpg3632911', 'brand': 'Generic', 'category4': 'Household Fans', 'name': "26 Inch Industrial Standing Water AC/Mist Fan 26''", 'price': '₦ 185,000', 'old_price': '', 'discount': '', 'rating': '4.5', 'total_reviews': '20'}
# {'price': <div class="prc">₦ 41,895</div>}
# {'old_price': <div class="old">₦ 51,895</div>}
# {'discount': <div class="bdg _dsct _sm">19%</div>}
# {'reviews_info': '5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': '102988831', 'full_id': 'binatone-16-inch-duo-power-series-standing-fan-a1692-102988831', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 16 Inch Duo Power Series Standing Fan (A1692)', 'price': '₦ 41,895', 'old_price': '₦ 51,895', 'discount': '19%', 'rating': '5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 84,000</div>}
# {'old_price': <div class="old">₦ 190,000</div>}
# {'discount': <div class="bdg _dsct _sm">56%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '265520890', 'full_id': 'binatone-16-inch-standing-fan-with-remote-control-a-1612-265520890', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 16-Inch Standing Fan With Remote Control A-1612', 'price': '₦ 84,000', 'old_price': '₦ 190,000', 'discount': '56%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 113,399</div>}
# {'old_price': <div class="old">₦ 166,180</div>}
# {'discount': <div class="bdg _dsct _sm">32%</div>}
# {'reviews_info': '4.3 out of 5(89)'}
#
#
# In scrape_product_info:  {'id': '26742221', 'full_id': 'binatone-20-inches-heavy-duty-industrial-fan-hdf-2021-black-26742221', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 20 Inches Heavy Duty Industrial Fan (HDF-2021) - Black', 'price': '₦ 113,399', 'old_price': '₦ 166,180', 'discount': '32%', 'rating': '4.3', 'total_reviews': '89'}
# {'price': <div class="prc">₦ 104,985</div>}
# {'old_price': <div class="old">₦ 115,500</div>}
# {'discount': <div class="bdg _dsct _sm">9%</div>}
# {'reviews_info': '4.1 out of 5(43)'}
#
#
# In scrape_product_info:  {'id': 'mpg3968470', 'full_id': 'standing-fan-industrial-20-inches-ox-mpg3968470', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Standing Fan Industrial 20" Inches', 'price': '₦ 104,985', 'old_price': '₦ 115,500', 'discount': '9%', 'rating': '4.1', 'total_reviews': '43'}
# {'price': <div class="prc">₦ 9,500</div>}
# {'old_price': <div class="old">₦ 25,000</div>}
# {'discount': <div class="bdg _dsct _sm">62%</div>}
# {'reviews_info': '4 out of 5(57)'}
#
#
# In scrape_product_info:  {'id': '316769940', 'full_id': 'iwin-mini-rechargeable-desktop-fan-316769940', 'brand': 'Iwin', 'category4': 'Household Fans', 'name': 'Iwin Mini Rechargeable Desktop Fan', 'price': '₦ 9,500', 'old_price': '₦ 25,000', 'discount': '62%', 'rating': '4', 'total_reviews': '57'}
# {'price': <div class="prc">₦ 105,500</div>}
# {'old_price': <div class="old">₦ 120,000</div>}
# {'discount': <div class="bdg _dsct _sm">12%</div>}
# {'reviews_info': '5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': 'mpg3352826', 'full_id': '20-inches-industrial-standing-fan-ox-mpg3352826', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 20" Inches Industrial Standing Fan', 'price': '₦ 105,500', 'old_price': '₦ 120,000', 'discount': '12%', 'rating': '5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 29,998</div>}
# {'old_price': <div class="old">₦ 50,000</div>}
# {'discount': <div class="bdg _dsct _sm">40%</div>}
# {'reviews_info': '4.3 out of 5(234)'}
#
#
# In scrape_product_info:  {'id': 'mpg4128518', 'full_id': 'plus-standing-fan-ox-mpg4128518', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Plus Standing Fan', 'price': '₦ 29,998', 'old_price': '₦ 50,000', 'discount': '40%', 'rating': '4.3', 'total_reviews': '234'}
# {'price': <div class="prc">₦ 14,256</div>}
# {'old_price': <div class="old">₦ 25,670</div>}
# {'discount': <div class="bdg _dsct _sm">44%</div>}
# {'reviews_info': '3 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '303228902', 'full_id': 'generic-portable-home-small-air-humidifier-3-speed-fan-white-303228902', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Portable Home Small Air Humidifier 3-Speed Fan - White', 'price': '₦ 14,256', 'old_price': '₦ 25,670', 'discount': '44%', 'rating': '3', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 49,000</div>}
# {'old_price': <div class="old">₦ 80,000</div>}
# {'discount': <div class="bdg _dsct _sm">39%</div>}
# {'reviews_info': '3.9 out of 5(12)'}
#
#
# In scrape_product_info:  {'id': 'mpg3968478', 'full_id': '18-inches-acdc-standing-fan-qsf-18r-qasa-mpg3968478', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches AC/DC Standing Fan QSF- Metal Blade', 'price': '₦ 49,000', 'old_price': '₦ 80,000', 'discount': '39%', 'rating': '3.9', 'total_reviews': '12'}
# {'price': <div class="prc">₦ 71,000</div>}
# {'old_price': <div class="old">₦ 200,000</div>}
# {'discount': <div class="bdg _dsct _sm">65%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '101910157', 'full_id': 'binatone-elegant-design-stand-fan-ital-1660-101910157', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone Elegant Design Stand Fan -  ITAL 1660', 'price': '₦ 71,000', 'old_price': '₦ 200,000', 'discount': '65%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 25,909</div>}
# {'old_price': <div class="old">₦ 28,143</div>}
# {'discount': <div class="bdg _dsct _sm">8%</div>}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '259886313', 'full_id': 'ox-18-inch-standing-fan-ventilator-259886313', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" Inch Standing Fan Ventilator', 'price': '₦ 25,909', 'old_price': '₦ 28,143', 'discount': '8%', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 28,290</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.5 out of 5(38)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147325', 'full_id': '18-plus-speedy-standing-fan-ox-mpg3147325', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" PLUS OX STANDING FAN', 'price': '₦ 28,290', 'old_price': '', 'discount': '', 'rating': '4.5', 'total_reviews': '38'}
# {'price': <div class="prc">₦ 25,900</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '344298136', 'full_id': 'generic-18-plus-electric-standing-fan-18-inches-344298136', 'brand': 'Generic', 'category4': 'Household Fans', 'name': '18" PLUS ELECTRIC STANDING FAN - 18 Inches', 'price': '₦ 25,900', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 24,900</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.7 out of 5(7)'}
#
#
# In scrape_product_info:  {'id': '265578281', 'full_id': 'bb-18-inches-standing-high-speed-fan-new-2024-265578281', 'brand': 'BB', 'category4': 'Household Fans', 'name': "BB 18' Inches Standing High Speed Fan New 2024", 'price': '₦ 24,900', 'old_price': '', 'discount': '', 'rating': '4.7', 'total_reviews': '7'}
# {'price': <div class="prc">₦ 97,995</div>}
# {'old_price': <div class="old">₦ 120,000</div>}
# {'discount': <div class="bdg _dsct _sm">18%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '367942325', 'full_id': 'qasa-26-industrial-fan-qpif-26-eco-free-torch-367942325', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 26" Industrial Fan QPIF-26 Eco +free Torch', 'price': '₦ 97,995', 'old_price': '₦ 120,000', 'discount': '18%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 122,000</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147365', 'full_id': 'standing-fan-industrial-26-inches-ox-mpg3147365', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Standing Fan Industrial 26" Inches', 'price': '₦ 122,000', 'old_price': '', 'discount': '', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 24,290</div>}
# {'old_price': <div class="old">₦ 118,908</div>}
# {'discount': <div class="bdg _dsct _sm">80%</div>}
# {'reviews_info': '4.4 out of 5(169)'}
#
#
# In scrape_product_info:  {'id': 'mpg3968457', 'full_id': '18-standing-fan-ox-fan-ox-mpg3968457', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18” Standing Fan Ox Plus Fan,', 'price': '₦ 24,290', 'old_price': '₦ 118,908', 'discount': '80%', 'rating': '4.4', 'total_reviews': '169'}
# {'price': <div class="prc">₦ 50,500</div>}
# {'old_price': <div class="old">₦ 75,000</div>}
# {'discount': <div class="bdg _dsct _sm">33%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '358456755', 'full_id': 'duravolt-rechargeable-table-wall-fan-with-solar-panel-358456755', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt Rechargeable Table/ Wall Fan With Solar Panel', 'price': '₦ 50,500', 'old_price': '₦ 75,000', 'discount': '33%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 69,500</div>}
# {'old_price': <div class="old">₦ 85,000</div>}
# {'discount': <div class="bdg _dsct _sm">18%</div>}
# {'reviews_info': '3.8 out of 5(13)'}
#
#
# In scrape_product_info:  {'id': '338892377', 'full_id': 'glamstar-18-inches-rechargeable-standing-fan-black-338892377', 'brand': 'Glamstar', 'category4': 'Household Fans', 'name': 'Glamstar 18 Inches Rechargeable Standing Fan Black', 'price': '₦ 69,500', 'old_price': '₦ 85,000', 'discount': '18%', 'rating': '3.8', 'total_reviews': '13'}
# {'price': <div class="prc">₦ 95,995</div>}
# {'old_price': <div class="old">₦ 120,000</div>}
# {'discount': <div class="bdg _dsct _sm">20%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '367619512', 'full_id': 'qasa-16-acdc-non-rechargeable-mist-fan-367619512', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 16"  Ac/Dc NON-RECHARGEABLE Mist Fan', 'price': '₦ 95,995', 'old_price': '₦ 120,000', 'discount': '20%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 24,990</div>}
# {'old_price': <div class="old">₦ 145,000</div>}
# {'discount': <div class="bdg _dsct _sm">83%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '259434230', 'full_id': 'ox-18-standing-electric-fan-free-gift-259434230', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" Standing Electric Fan + Free Gift', 'price': '₦ 24,990', 'old_price': '₦ 145,000', 'discount': '83%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 73,000</div>}
# {'old_price': <div class="old">₦ 155,000</div>}
# {'discount': <div class="bdg _dsct _sm">53%</div>}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '359915492', 'full_id': 'generic-16inches-rechargeable-acdc-solar-fan-with-20w-panel-and-one-led-bulb-359915492', 'brand': 'Generic', 'category4': 'Household Fans', 'name': '16inches Rechargeable AC/DC solar fan with 20w panel and one Led bulb', 'price': '₦ 73,000', 'old_price': '₦ 155,000', 'discount': '53%', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 4,590</div>}
# {'old_price': <div class="old">₦ 7,265</div>}
# {'discount': <div class="bdg _dsct _sm">37%</div>}
# {'reviews_info': '3.9 out of 5(253)'}
#
#
# In scrape_product_info:  {'id': '204930020', 'full_id': 'iyowei-rechargeable-table-hand-fan-mobile-phone-holder-204930020', 'brand': 'iYOWEI', 'category4': 'Household Fans', 'name': 'iYOWEI Rechargeable Table Hand Fan Mobile Phone Holder', 'price': '₦ 4,590', 'old_price': '₦ 7,265', 'discount': '37%', 'rating': '3.9', 'total_reviews': '253'}
# {'price': <div class="prc">₦ 38,950</div>}
# {'old_price': <div class="old">₦ 143,000</div>}
# {'discount': <div class="bdg _dsct _sm">73%</div>}
# {'reviews_info': '4.2 out of 5(12)'}
#
#
# In scrape_product_info:  {'id': '67172965', 'full_id': 'qasa-18-standing-fan-qsf-18721-eco-68w-metal-blades-67172965', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18" Standing Fan QSF-18721 Eco 68W Metal Blades', 'price': '₦ 38,950', 'old_price': '₦ 143,000', 'discount': '73%', 'rating': '4.2', 'total_reviews': '12'}
# {'price': <div class="prc">₦ 52,499</div>}
# {'old_price': <div class="old">₦ 60,000</div>}
# {'discount': <div class="bdg _dsct _sm">13%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '363416143', 'full_id': 'qasa-12-inches-rechargeable-table-fan-with-solar-and-bulbs-363416143', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 12 Inches Rechargeable Table Fan With Solar And Bulbs', 'price': '₦ 52,499', 'old_price': '₦ 60,000', 'discount': '13%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 67,500</div>}
# {'old_price': <div class="old">₦ 78,000</div>}
# {'discount': <div class="bdg _dsct _sm">13%</div>}
# {'reviews_info': '5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': 'mpg3964554', 'full_id': '18-inch-typhoon-series-standing-fan-ts-1880-mk2-black-binatone-mpg3964554', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 18 Inch Standing Fan TS-1880 .+Free Ext', 'price': '₦ 67,500', 'old_price': '₦ 78,000', 'discount': '13%', 'rating': '5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 25,990</div>}
# {'old_price': <div class="old">₦ 72,490</div>}
# {'discount': <div class="bdg _dsct _sm">64%</div>}
# {'reviews_info': '4.2 out of 5(1022)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147331', 'full_id': 'plus-18-stand-fan-ox-mpg3147331', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18inch STANDING FAN-BLACK+ Free Gift Inside', 'price': '₦ 25,990', 'old_price': '₦ 72,490', 'discount': '64%', 'rating': '4.2', 'total_reviews': '1022'}
# {'price': <div class="prc">₦ 69,500</div>}
# {'old_price': <div class="old">₦ 90,400</div>}
# {'discount': <div class="bdg _dsct _sm">23%</div>}
# {'reviews_info': '4.6 out of 5(9)'}
#
#
# In scrape_product_info:  {'id': 'mpg3632956', 'full_id': '18-inches-acdc-standing-fan-20-watts-solar-panel-qasa-mpg3632956', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches AC/DC Standing Fan + 20 Watts SOLAR PANEL', 'price': '₦ 69,500', 'old_price': '₦ 90,400', 'discount': '23%', 'rating': '4.6', 'total_reviews': '9'}
# {'price': <div class="prc">₦ 23,500</div>}
# {'old_price': <div class="old">₦ 25,000</div>}
# {'discount': <div class="bdg _dsct _sm">6%</div>}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147396', 'full_id': 'short-blade-ceiling-fan-24-inches-coffee-brownwhite-qasa-mpg3147396', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa Short Blade Ceiling Fan -24 Inches COFFEE BROWN/WHITE', 'price': '₦ 23,500', 'old_price': '₦ 25,000', 'discount': '6%', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 68,000</div>}
# {'old_price': <div class="old">₦ 70,000</div>}
# {'discount': <div class="bdg _dsct _sm">3%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '367170706', 'full_id': 'qasa-18-inches-acdc-standing-fan-20-watts-solar-panel-367170706', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches AC/DC Standing Fan + 20 Watts SOLAR PANEL', 'price': '₦ 68,000', 'old_price': '₦ 70,000', 'discount': '3%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 77,995</div>}
# {'old_price': <div class="old">₦ 87,500</div>}
# {'discount': <div class="bdg _dsct _sm">11%</div>}
# {'reviews_info': '4.5 out of 5(12)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147327', 'full_id': 'industrial-wall-fan-18-inches-ox-mpg3147327', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Industrial Wall Fan - 18 Inches', 'price': '₦ 77,995', 'old_price': '₦ 87,500', 'discount': '11%', 'rating': '4.5', 'total_reviews': '12'}
# {'price': <div class="prc">₦ 57,799</div>}
# {'old_price': <div class="old">₦ 87,050</div>}
# {'discount': <div class="bdg _dsct _sm">34%</div>}
# {'reviews_info': '4.6 out of 5(19)'}
#
#
# In scrape_product_info:  {'id': '202233725', 'full_id': 'binatone-1.6-metres-stand-fan-mode-a-1810-black-202233725', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 1.6 Metres Stand Fan Mode (A-1810) - Black', 'price': '₦ 57,799', 'old_price': '₦ 87,050', 'discount': '34%', 'rating': '4.6', 'total_reviews': '19'}
# {'price': <div class="prc">₦ 114,802</div>}
# {'old_price': <div class="old">₦ 135,700</div>}
# {'discount': <div class="bdg _dsct _sm">15%</div>}
# {'reviews_info': '4.2 out of 5(845)'}
#
#
# In scrape_product_info:  {'id': '71338441', 'full_id': 'sun-king-solar-fan-with-20w-solar-panel-71338441', 'brand': 'Sun King', 'category4': 'Household Fans', 'name': 'Sun King Solar Fan With 20W Solar Panel', 'price': '₦ 114,802', 'old_price': '₦ 135,700', 'discount': '15%', 'rating': '4.2', 'total_reviews': '845'}
# {'price': <div class="prc">₦ 48,000</div>}
# {'old_price': <div class="old">₦ 79,000</div>}
# {'discount': <div class="bdg _dsct _sm">39%</div>}
# {'reviews_info': '5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': 'mpg2940485', 'full_id': '18-inches-acdc-standing-fan-remote-non-rechargeable-qasa-mpg2940485', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches AC/DC Standing Fan + Remote (Non Rechargeable)', 'price': '₦ 48,000', 'old_price': '₦ 79,000', 'discount': '39%', 'rating': '5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 40,995</div>}
# {'old_price': <div class="old">₦ 50,000</div>}
# {'discount': <div class="bdg _dsct _sm">18%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '366885126', 'full_id': 'duravolt-16-dc-standing-fan-dsf-163-dc-366885126', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 16" DC STANDING FAN, DSF-163 Dc', 'price': '₦ 40,995', 'old_price': '₦ 50,000', 'discount': '18%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 6,138</div>}
# {'old_price': <div class="old">₦ 18,714</div>}
# {'discount': <div class="bdg _dsct _sm">67%</div>}
# {'reviews_info': '3.3 out of 5(24)'}
#
#
# In scrape_product_info:  {'id': '257186978', 'full_id': 'generic-portable-neck-fan-rechargeable-led-display-5-speeds-257186978', 'brand': 'Generic', 'category4': 'USB Fans', 'name': 'Portable Neck Fan Rechargeable LED Display 5 Speeds', 'price': '₦ 6,138', 'old_price': '₦ 18,714', 'discount': '67%', 'rating': '3.3', 'total_reviews': '24'}
# {'price': <div class="prc">₦ 89,990</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.5 out of 5(35)'}
#
#
# In scrape_product_info:  {'id': '72087099', 'full_id': 'ox-industrial-18-inches-standing-fan-72087099', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Industrial 18" Inches Standing Fan', 'price': '₦ 89,990', 'old_price': '', 'discount': '', 'rating': '4.5', 'total_reviews': '35'}
# {'price': <div class="prc">₦ 39,199</div>}
# {'old_price': <div class="old">₦ 66,500</div>}
# {'discount': <div class="bdg _dsct _sm">41%</div>}
# {'reviews_info': '4.4 out of 5(923)'}
#
#
# In scrape_product_info:  {'id': 'mpg4310477', 'full_id': '12-inch-rechargeable-table-fan-cf025-12-lontor-mpg4310477', 'brand': 'Lontor', 'category4': 'Household Fans', 'name': 'Lontor 12 Inch Rechargeable Table Fan Cf025-12', 'price': '₦ 39,199', 'old_price': '₦ 66,500', 'discount': '41%', 'rating': '4.4', 'total_reviews': '923'}
# {'price': <div class="prc">₦ 139,000</div>}
# {'old_price': <div class="old">₦ 170,000</div>}
# {'discount': <div class="bdg _dsct _sm">18%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '112757338', 'full_id': 'binatone-stand-fan-elite-series-18-inches-es-1800-brass-metal-112757338', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone Stand Fan Elite Series 18 Inches ES-1800 - Brass (Metal)', 'price': '₦ 139,000', 'old_price': '₦ 170,000', 'discount': '18%', 'rating': '', 'total_reviews': ''}
# Page 2 done!
# {'price': <div class="prc">₦ 28,000</div>}
# {'old_price': <div class="old">₦ 30,000</div>}
# {'discount': <div class="bdg _dsct _sm">7%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '374347383', 'full_id': 'duravolt-7inches-rechargeable-table-fansolar-panelbulbs-374347383', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 7inches Rechargeable Table Fan+Solar Panel+Bulbs', 'price': '₦ 28,000', 'old_price': '₦ 30,000', 'discount': '7%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 52,499</div>}
# {'old_price': <div class="old">₦ 65,000</div>}
# {'discount': <div class="bdg _dsct _sm">19%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '363414363', 'full_id': 'qasa-12-inches-rechargeable-table-fan-with-solar-and-bulbs-363414363', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 12 Inches Rechargeable Table Fan With Solar And Bulbs', 'price': '₦ 52,499', 'old_price': '₦ 65,000', 'discount': '19%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 29,900</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.3 out of 5(9)'}
#
#
# In scrape_product_info:  {'id': 'mpg1580417', 'full_id': 'heavy-breeze-wall-fan-18-inches-century-mpg1580417', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Heavy Breeze Wall Fan 18" Inches', 'price': '₦ 29,900', 'old_price': '', 'discount': '', 'rating': '4.3', 'total_reviews': '9'}
# {'price': <div class="prc">₦ 89,500</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147353', 'full_id': 'industrial-18-inches-standing-fan-ox-mpg3147353', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Industrial 18" Inches Standing Fan', 'price': '₦ 89,500', 'old_price': '', 'discount': '', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 62,499</div>}
# {'old_price': <div class="old">₦ 85,620</div>}
# {'discount': <div class="bdg _dsct _sm">27%</div>}
# {'reviews_info': '4.4 out of 5(182)'}
#
#
# In scrape_product_info:  {'id': 'mpg1675136', 'full_id': 'elegant-design-stand-fan-ital-1660-binatone-mpg1675136', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone 1.6 Metre Stand Fan (ITAL 1660) - Black', 'price': '₦ 62,499', 'old_price': '₦ 85,620', 'discount': '27%', 'rating': '4.4', 'total_reviews': '182'}
# {'price': <div class="prc">₦ 28,250</div>}
# {'old_price': <div class="old">₦ 35,000</div>}
# {'discount': <div class="bdg _dsct _sm">19%</div>}
# {'reviews_info': '4 out of 5(36)'}
#
#
# In scrape_product_info:  {'id': 'mpg4128525', 'full_id': '18-adjustable-standing-fan-black-ox-mpg4128525', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" PLUS ELECTRIC STANDING FAN - 18 Inches', 'price': '₦ 28,250', 'old_price': '₦ 35,000', 'discount': '19%', 'rating': '4', 'total_reviews': '36'}
# {'price': <div class="prc">₦ 28,500</div>}
# {'old_price': <div class="old">₦ 30,000</div>}
# {'discount': <div class="bdg _dsct _sm">5%</div>}
# {'reviews_info': '3 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '363415725', 'full_id': 'duravolt-7inches-rechargeable-table-fansolar-panelbulbs-363415725', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 7inches Rechargeable Table Fan+Solar Panel+Bulbs', 'price': '₦ 28,500', 'old_price': '₦ 30,000', 'discount': '5%', 'rating': '3', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 49,995</div>}
# {'old_price': <div class="old">₦ 50,000</div>}
# {'discount': <div class="bdg _dsct _sm">1%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '366846944', 'full_id': 'duravolt-18-dc-standing-fan-dsf-183-dc-366846944', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 18" DC STANDING FAN, DSF-183 Dc', 'price': '₦ 49,995', 'old_price': '₦ 50,000', 'discount': '1%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 25,000</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '3 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '323263228', 'full_id': 'best-buy-bb-18-inches-standing-high-speed-fan-new-2024-323263228', 'brand': 'Best Buy', 'category4': 'Household Fans', 'name': "Best Buy BB 18' Inches Standing High Speed Fan New 2024", 'price': '₦ 25,000', 'old_price': '', 'discount': '', 'rating': '3', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 9,200</div>}
# {'old_price': <div class="old">₦ 20,978</div>}
# {'discount': <div class="bdg _dsct _sm">56%</div>}
# {'reviews_info': '4 out of 5(98)'}
#
#
# In scrape_product_info:  {'id': '232165344', 'full_id': 'generic-q3-desk-fan-portable-personal-fan-digital-display-232165344', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Q3 Desk Fan Portable Personal Fan Digital DIsplay', 'price': '₦ 9,200', 'old_price': '₦ 20,978', 'discount': '56%', 'rating': '4', 'total_reviews': '98'}
# {'price': <div class="prc">₦ 25,490</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '311833972', 'full_id': 'ox-spacetek-18-inches-standing-industrial-fan-2-years-warranty-311833972', 'brand': 'Ox', 'category4': 'Household Fans', 'name': "Ox Spacetek 18' Inches Standing Industrial Fan 2 Years Warranty", 'price': '₦ 25,490', 'old_price': '', 'discount': '', 'rating': '4', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 65,000</div>}
# {'old_price': <div class="old">₦ 90,000</div>}
# {'discount': <div class="bdg _dsct _sm">28%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '356188000', 'full_id': 'silver-crest-16-solar-rechargeable-fan-with-solar-panel-356188000', 'brand': 'Silver Crest', 'category4': 'Household Fans', 'name': 'Silver Crest 16" Solar Rechargeable Fan With Solar Panel', 'price': '₦ 65,000', 'old_price': '₦ 90,000', 'discount': '28%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 118,800</div>}
# {'old_price': <div class="old">₦ 155,900</div>}
# {'discount': <div class="bdg _dsct _sm">24%</div>}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '35771820', 'full_id': 'ox-26-inches-industrial-standing-fan-26-ox-industrial-fan-35771820', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 26 Inches Industrial Standing Fan - 26" OX Industrial Fan', 'price': '₦ 118,800', 'old_price': '₦ 155,900', 'discount': '24%', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 22,889</div>}
# {'old_price': <div class="old">₦ 32,696</div>}
# {'discount': <div class="bdg _dsct _sm">30%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '291951916', 'full_id': 'generic-tower-type-usb-electric-fan-leafless-air-conditioning-fan-291951916', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Tower Type USB Electric Fan Leafless Air-conditioning Fan', 'price': '₦ 22,889', 'old_price': '₦ 32,696', 'discount': '30%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 49,999</div>}
# {'old_price': <div class="old">₦ 60,000</div>}
# {'discount': <div class="bdg _dsct _sm">17%</div>}
# {'reviews_info': '4.8 out of 5(5)'}
#
#
# In scrape_product_info:  {'id': '269976599', 'full_id': 'duravolt-solar-ceiling-fan-acdc-269976599', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt Solar Ceiling Fan AC/DC', 'price': '₦ 49,999', 'old_price': '₦ 60,000', 'discount': '17%', 'rating': '4.8', 'total_reviews': '5'}
# {'price': <div class="prc">₦ 101,170</div>}
# {'old_price': <div class="old">₦ 175,999</div>}
# {'discount': <div class="bdg _dsct _sm">43%</div>}
# {'reviews_info': '4.4 out of 5(132)'}
#
#
# In scrape_product_info:  {'id': 'mpg3147366', 'full_id': 'standing-fan-industrial-26-inches-ox-mpg3147366', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Standing Fan Industrial 26" Inches', 'price': '₦ 101,170', 'old_price': '₦ 175,999', 'discount': '43%', 'rating': '4.4', 'total_reviews': '132'}
# {'price': <div class="prc">₦ 26,900</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '4.7 out of 5(3)'}
#
#
# ...
# {'price': <div class="prc">₦ 85,500</div>}
# {'old_price': <div class="old">₦ 98,000</div>}
# {'discount': <div class="bdg _dsct _sm">13%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '288015784', 'full_id': 'duravolt-16-rechargeable-fan-solar-panel-2-bulbs3-in-1-288015784', 'brand': 'Duravolt', 'category4': 'Household Fans', 'name': 'Duravolt 16” Rechargeable Fan +Solar Panel + 2-Bulbs(3 In 1)', 'price': '₦ 85,500', 'old_price': '₦ 98,000', 'discount': '13%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 7,506</div>}
# {'old_price': <div class="old">₦ 13,676</div>}
# {'discount': <div class="bdg _dsct _sm">45%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '308193853', 'full_id': 'generic-p11-mobile-phone-cooler-cooling-fan-game-pad-holder-bracket-308193853', 'brand': 'Generic', 'category4': 'Fans & Cooling', 'name': 'P11 Mobile Phone Cooler Cooling Fan Game Pad Holder Bracket', 'price': '₦ 7,506', 'old_price': '₦ 13,676', 'discount': '45%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 6,750</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '292866557', 'full_id': 'generic-mini-portable-usb-rechargeable-hand-fan-292866557', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Mini Portable USB Rechargeable Hand Fan', 'price': '₦ 6,750', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 49,900</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '66896224', 'full_id': 'ox-ceiling-fan-mega-62-inches-66896224', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Ceiling Fan- Mega 62 Inches', 'price': '₦ 49,900', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 85,000</div>}
# {'old_price': <div class="old">₦ 90,000</div>}
# {'discount': <div class="bdg _dsct _sm">6%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '360553996', 'full_id': 'solar-rechargeable-standing-fan-solar-panelstrong-quality-360553996', 'brand': 'Solar', 'category4': 'Household Fans', 'name': 'Solar RECHARGEABLE STANDING FAN + Solar Panel_STRONG Quality', 'price': '₦ 85,000', 'old_price': '₦ 90,000', 'discount': '6%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 15,250</div>}
# {'old_price': <div class="old">₦ 21,785</div>}
# {'discount': <div class="bdg _dsct _sm">30%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '239808072', 'full_id': 'generic-retractable-floor-standing-fan-239808072', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Retractable Floor Standing Fan', 'price': '₦ 15,250', 'old_price': '₦ 21,785', 'discount': '30%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 11,999</div>}
# {'old_price': <div class="old">₦ 22,000</div>}
# {'discount': <div class="bdg _dsct _sm">45%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '289589563', 'full_id': 'dp-portable-soft-touch-mini-fan-dp-7609-289589563', 'brand': 'Dp', 'category4': 'Household Fans', 'name': 'Dp Portable Soft Touch Mini Fan DP-7609', 'price': '₦ 11,999', 'old_price': '₦ 22,000', 'discount': '45%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 102,856</div>}
# {'old_price': <div class="old">₦ 203,698</div>}
# {'discount': <div class="bdg _dsct _sm">50%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '349724436', 'full_id': 'generic-waterproof-premium-bathroom-extractor-fan-ducting-4-for-kitchen-toilet-4inch-khg100-349724436', 'brand': 'Generic', 'category4': 'Large Appliance Accessories', 'name': 'Waterproof Premium Bathroom Extractor Fan Ducting 4" For Kitchen Toilet 4inch Khg100', 'price': '₦ 102,856', 'old_price': '₦ 203,698', 'discount': '50%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 4,250</div>}
# {'old_price': <div class="old">₦ 5,100</div>}
# {'discount': <div class="bdg _dsct _sm">17%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '128268129', 'full_id': 'generic-r39-e14-lava-lamp-light-bulb-small-screw-25w-220v-warm-white-for-128268129', 'brand': 'Generic', 'category4': 'Ceiling Fans & Accessories', 'name': 'R39 E14 Lava Lamp Light Bulb Small Screw 25W 220V Warm White For', 'price': '₦ 4,250', 'old_price': '₦ 5,100', 'discount': '17%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 57,900</div>}
# {'old_price': <div class="old">₦ 59,000</div>}
# {'discount': <div class="bdg _dsct _sm">2%</div>}
# {'reviews_info': '4.8 out of 5(8)'}
#
#
# In scrape_product_info:  {'id': 'mpg4128538', 'full_id': '18-inches-electric-standing-fan-qsf-18721k18-qasa-mpg4128538', 'brand': 'Qasa', 'category4': 'Household Fans', 'name': 'Qasa 18 Inches Electric Standing Fan - QSF-18721K18', 'price': '₦ 57,900', 'old_price': '₦ 59,000', 'discount': '2%', 'rating': '4.8', 'total_reviews': '8'}
# {'price': <div class="prc">₦ 87,000</div>}
# {'old_price': <div class="old">₦ 150,000</div>}
# {'discount': <div class="bdg _dsct _sm">42%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '359274452', 'full_id': 'solar-16-solar-rechargeable-fan-with-led-light-bulb.-359274452', 'brand': 'Solar', 'category4': 'Household Fans', 'name': 'Solar 16" Solar Rechargeable Fan With  LED Light &Bulb.', 'price': '₦ 87,000', 'old_price': '₦ 150,000', 'discount': '42%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 57,000</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '3 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '79343531', 'full_id': 'orl-giant-60-inches-ceiling-fan-79343531', 'brand': 'Orl', 'category4': 'Ceiling Fans & Accessories', 'name': 'Orl Giant 60 Inches Ceiling Fan', 'price': '₦ 57,000', 'old_price': '', 'discount': '', 'rating': '3', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 31,000</div>}
# {'old_price': <div class="old">₦ 40,000</div>}
# {'discount': <div class="bdg _dsct _sm">23%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '162093236', 'full_id': 'generic-duct-extractor-fan-ceiling-type-8-inches-162093236', 'brand': 'Generic', 'category4': 'Bathroom Fixtures', 'name': 'Duct Extractor Fan - Ceiling Type - 8 Inches', 'price': '₦ 31,000', 'old_price': '₦ 40,000', 'discount': '23%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 11,500</div>}
# {'old_price': <div class="old">₦ 16,000</div>}
# {'discount': <div class="bdg _dsct _sm">28%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '326761921', 'full_id': 'generic-foldable-table-fan-clip-326761921', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'Foldable Table Fan Clip', 'price': '₦ 11,500', 'old_price': '₦ 16,000', 'discount': '28%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 138,000</div>}
# {'old_price': <div class="old">₦ 150,000</div>}
# {'discount': <div class="bdg _dsct _sm">8%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '367114028', 'full_id': 'binatone-rechargeable-fan-with-lithium-ion-batteries-rcfm-1875-367114028', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone Rechargeable Fan With Lithium-Ion Batteries RCFM-1875', 'price': '₦ 138,000', 'old_price': '₦ 150,000', 'discount': '8%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 103,999</div>}
# {'old_price': <div class="old">₦ 300,000</div>}
# {'discount': <div class="bdg _dsct _sm">65%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '228830683', 'full_id': 'ox-18-plus-rechargeable-standing-228830683', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" Plus Rechargeable Standing', 'price': '₦ 103,999', 'old_price': '₦ 300,000', 'discount': '65%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 8,500</div>}
# {'old_price': None}
# {'discount': None}
# {'reviews_info': '1 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '91369697', 'full_id': 'generic-handy-rechargeble-mini-fan-91369697', 'brand': 'Generic', 'category4': 'Fans & Cooling', 'name': 'HANDY RECHARGEBLE MINI FAN', 'price': '₦ 8,500', 'old_price': '', 'discount': '', 'rating': '1', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 28,500</div>}
# {'old_price': <div class="old">₦ 39,000</div>}
# {'discount': <div class="bdg _dsct _sm">27%</div>}
# {'reviews_info': '5 out of 5(1)'}
#
#
# In scrape_product_info:  {'id': '289918260', 'full_id': 'ox-plus-standing-fan-289918260', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Plus Standing Fan', 'price': '₦ 28,500', 'old_price': '₦ 39,000', 'discount': '27%', 'rating': '5', 'total_reviews': '1'}
# {'price': <div class="prc">₦ 19,300</div>}
# {'old_price': <div class="old">₦ 26,000</div>}
# {'discount': <div class="bdg _dsct _sm">26%</div>}
# {'reviews_info': '5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': '303779544', 'full_id': 'dp-rechargeable-fan-4000mah-with-led-lights-303779544', 'brand': 'Dp', 'category4': 'Household Fans', 'name': 'Dp Rechargeable Fan 4000mAh With LED LIGHTs', 'price': '₦ 19,300', 'old_price': '₦ 26,000', 'discount': '26%', 'rating': '5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 44,499</div>}
# {'old_price': <div class="old">₦ 50,000</div>}
# {'discount': <div class="bdg _dsct _sm">11%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '188553967', 'full_id': 'nunix-extra-breeze-high-quality-standing-fan-18-inches-188553967', 'brand': 'Nunix', 'category4': 'Household Fans', 'name': 'Nunix Extra Breeze High Quality Standing Fan - 18 Inches', 'price': '₦ 44,499', 'old_price': '₦ 50,000', 'discount': '11%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 9,500</div>}
# {'old_price': <div class="old">₦ 25,000</div>}
# {'discount': <div class="bdg _dsct _sm">62%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '296834475', 'full_id': 'dp-rechargeable-handheld-with-base-and-led-light-296834475', 'brand': 'Dp', 'category4': 'Household Fans', 'name': 'Dp Rechargeable handheld with base and Led light', 'price': '₦ 9,500', 'old_price': '₦ 25,000', 'discount': '62%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 39,900</div>}
# {'old_price': <div class="old">₦ 60,000</div>}
# {'discount': <div class="bdg _dsct _sm">34%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '290124779', 'full_id': 'fan-dp-8000mah-oscillating-rechargeable-fan-290124779', 'brand': 'Fan', 'category4': 'Household Fans', 'name': 'Fan Dp 8000mAh Oscillating Rechargeable Fan', 'price': '₦ 39,900', 'old_price': '₦ 60,000', 'discount': '34%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 75,000</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '205966756', 'full_id': 'essentiel-pedestal-digital-fan-205966756', 'brand': 'Essentiel', 'category4': 'Household Fans', 'name': 'Essentiel Pedestal Digital Fan', 'price': '₦ 75,000', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 31,500</div>}
# {'old_price': <div class="old">₦ 40,400</div>}
# {'discount': <div class="bdg _dsct _sm">22%</div>}
# {'reviews_info': '3.5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': 'mpg3352812', 'full_id': '18-plus-standing-quality-electric-fan-18-inches-ox-mpg3352812', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox 18" PLUS STANDING ELECTRIC FAN - 18 Inches', 'price': '₦ 31,500', 'old_price': '₦ 40,400', 'discount': '22%', 'rating': '3.5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 31,349</div>}
# {'old_price': <div class="old">₦ 32,999</div>}
# {'discount': <div class="bdg _dsct _sm">5%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '289903333', 'full_id': 'generic-incredible-metal-and-wood-side-tablestool-289903333', 'brand': 'Generic', 'category4': 'Ceiling Fans & Accessories', 'name': 'INCREDIBLE METAL AND WOOD SIDE TABLE/STOOL', 'price': '₦ 31,349', 'old_price': '₦ 32,999', 'discount': '5%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 21,200</div>}
# {'old_price': <div class="old">₦ 25,000</div>}
# {'discount': <div class="bdg _dsct _sm">15%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '373433313', 'full_id': 'generic-smart-control-ceiling-fan-light-373433313', 'brand': 'Generic', 'category4': 'Ceiling Fans & Accessories', 'name': 'Smart Control Ceiling Fan Light', 'price': '₦ 21,200', 'old_price': '₦ 25,000', 'discount': '15%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 24,999</div>}
# {'old_price': <div class="old">₦ 30,000</div>}
# {'discount': <div class="bdg _dsct _sm">17%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '356389982', 'full_id': 'generic-double-pole-clothes-hanger-rack-with-adjustable-bars-356389982', 'brand': 'Generic', 'category4': 'Stroller Fans', 'name': 'Double Pole Clothes Hanger Rack With Adjustable Bars', 'price': '₦ 24,999', 'old_price': '₦ 30,000', 'discount': '17%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 49,100</div>}
# {'old_price': <div class="old">₦ 81,800</div>}
# {'discount': <div class="bdg _dsct _sm">40%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '102613824', 'full_id': 'generic-hot-mobile-phone-heat-sink-gaming-cooling-fan-for-fan-102613824', 'brand': 'Generic', 'category4': 'Fans & Cooling', 'name': 'Hot Mobile Phone Heat Sink Gaming Cooling Fan For Fan', 'price': '₦ 49,100', 'old_price': '₦ 81,800', 'discount': '40%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 27,994</div>}
# {'old_price': <div class="old">₦ 40,000</div>}
# {'discount': <div class="bdg _dsct _sm">30%</div>}
# {'reviews_info': '3.5 out of 5(2)'}
#
#
# In scrape_product_info:  {'id': 'mpg3968453', 'full_id': 'hi-performing-ox-18-plus-standing-fan-with-silent-breeze-ox-mpg3968453', 'brand': 'Ox', 'category4': 'Household Fans', 'name': 'Ox Hi Breeze Ox 18 Plus Standing Fan - Black', 'price': '₦ 27,994', 'old_price': '₦ 40,000', 'discount': '30%', 'rating': '3.5', 'total_reviews': '2'}
# {'price': <div class="prc">₦ 172,999</div>}
# {'old_price': <div class="old">₦ 405,000</div>}
# {'discount': <div class="bdg _dsct _sm">57%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '98071663', 'full_id': 'binatone-rechargeable-fan-18-with-remote-control-rcf-1855-98071663', 'brand': 'Binatone', 'category4': 'Household Fans', 'name': 'Binatone Rechargeable Fan 18" With Remote Control RCF-1855', 'price': '₦ 172,999', 'old_price': '₦ 405,000', 'discount': '57%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 55,000</div>}
# {'old_price': <div class="old">₦ 65,000</div>}
# {'discount': <div class="bdg _dsct _sm">15%</div>}
# reviews_info isn't available
# In scrape_product_info:  {'id': '311305298', 'full_id': 'qasa-quality-56-inches-remote-controlled-only-ceiling-fan-311305298', 'brand': 'Qasa', 'category4': 'Ceiling Fans & Accessories', 'name': 'Qasa Quality 56 Inches Remote Controlled Only Ceiling Fan', 'price': '₦ 55,000', 'old_price': '₦ 65,000', 'discount': '15%', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 16,000</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '290689568', 'full_id': 'arctic-air-arctic-airr-freedomtm-290689568', 'brand': 'Arctic Air', 'category4': 'Household Fans', 'name': 'Arctic Air Arctic Air® Freedom™', 'price': '₦ 16,000', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# {'price': <div class="prc">₦ 55,052</div>}
# {'old_price': None}
# {'discount': None}
# reviews_info isn't available
# In scrape_product_info:  {'id': '253733684', 'full_id': 'generic-white-portable-hand-held-fan-253733684', 'brand': 'Generic', 'category4': 'Household Fans', 'name': 'White Portable Hand-held Fan', 'price': '₦ 55,052', 'old_price': '', 'discount': '', 'rating': '', 'total_reviews': ''}
# Page 50 done!
